# %%
import requests
import pandas as pd

# %%
url = "http://purl.obolibrary.org/obo/GAZ_00002641"
response = requests.request("GET", url)

# %%
# team = response.json()['sports'][0]['leagues'][0]['teams'][0]['team']
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/f1/lib/python3.9/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     <a href='file:///Users/harsh/miniconda3/envs/f1/lib/python3.9/site-packages/requests/models.py?line=908'>909</a> try:
# --> <a href='file:///Users/harsh/miniconda3/envs/f1/lib/python3.9/site-packages/requests/models.py?line=909'>910</a>     return complexjson.loads(self.text, **kwargs)
#     <a href='file:///Users/harsh/miniconda3/envs/f1/lib/python3.9/site-packages/requests/models.py?line=910'>911</a> except JSONDecodeError as e:
#     <a href='file:///Users/harsh/miniconda3/envs/f1/lib/python3.9/site-packages/requests/models.py?line=911'>912</a>     # Catch JSON-related errors and raise as requests.JSONDecodeError
# ...
